# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %%
import zipfile
import os

# Define the zip file path and extraction path
zip_file_path = r"C:\Users\HP\Desktop\Teeth DataSet.zip"
extract_path = r"C:\Users\HP\Desktop\Teeth DataSet"

# Create the extraction folder if it doesn't exist
os.makedirs(extract_path, exist_ok=True)

# Extract the contents of the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
import os
import shutil

# Paths
test_dir = r"C:\Users\HP\Desktop\Teeth DataSet\Teeth_Dataset\Testing"
selected_test_dir =r"C:\Users\HP\Desktop\Teeth DataSet\Teeth_Dataset\New_Testing"

# Create the new directory if it doesn't exist
if not os.path.exists(selected_test_dir):
    os.makedirs(selected_test_dir)

# List all folders in the test directory
all_folders = sorted([f for f in os.listdir(test_dir) if os.path.isdir(os.path.join(test_dir, f))])

# Select the first 7 folders
selected_folders = all_folders[:7]

# Move the selected folders to the new directory
for folder in selected_folders:
    src = os.path.join(test_dir, folder)
    dst = os.path.join(selected_test_dir, folder)
    shutil.copytree(src, dst)

print(f"Selected folders: {selected_folders}")
# Out:
# Selected folders: ['CaS', 'CoS', 'Gum', 'MC', 'OC', 'OLP', 'OT']

# %%
# Define image size and batch size
image_size = (150, 150)  # Example size, adjust as needed
batch_size = 32

# Data augmentation settings
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    #shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

# Load data from directories
train_generator = train_datagen.flow_from_directory(
   r"C:\Users\HP\Desktop\Teeth DataSet\Teeth_Dataset\Training",
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    r"C:\Users\HP\Desktop\Teeth DataSet\Teeth_Dataset\Validation",
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    r"C:\Users\HP\Desktop\Teeth DataSet\Teeth_Dataset\New_Testing",
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 3087 images belonging to 7 classes.
# Found 1028 images belonging to 7 classes.
# Found 1028 images belonging to 7 classes.

# %%
def plot_images(generator, num_images=5):
    plt.figure(figsize=(15, 15))
    for i in range(num_images):
        image, label = next(generator)
        plt.subplot(1, num_images, i+1)
        plt.imshow(image[0])
        # Get the class index with the highest probability and use it to fetch the label
        predicted_class_index = label[0].argmax()
        predicted_class_label = list(generator.class_indices.keys())[list(generator.class_indices.values()).index(predicted_class_index)]
        plt.title(f"Label: {predicted_class_label}")
        plt.axis('off')
    plt.show()

# Visualize images from each set
plot_images(train_generator)
plot_images(val_generator)
plot_images(test_generator)

# %%
#def conv_block(x, filters, num_conv_layers):
#    for _ in range(num_conv_layers):
#        x = layers.Conv2D(filters, (3, 3), padding='same', activation='relu')(x)
#    x = layers.MaxPooling2D((2, 2))(x)
#    return x

#def vgg16_model(input_shape=(224, 224, 3), num_classes=7):
#    inputs = tf.keras.Input(shape=input_shape)

    # Convolutional layers
#    x = conv_block(inputs, 64, 2)
#    x = conv_block(x, 128, 2)
#    x = conv_block(x, 256, 3)
#    x = conv_block(x, 512, 3)
#    x = conv_block(x, 512, 3)

    # Fully connected layers
#    x = layers.Flatten()(x)
#    x = layers.Dense(4096, activation='relu')(x)
#    x = layers.Dropout(0.5)(x)
#    x = layers.Dense(4096, activation='relu')(x)
#    x = layers.Dropout(0.5)(x)
#    outputs = layers.Dense(num_classes, activation='softmax')(x)

#    model = models.Model(inputs, outputs)
#    return model

# %%
#model = vgg16_model(input_shape=(150, 150, 3), num_classes=7)

# %%
model = models.Sequential([
    # First Convolutional Block
    layers.Input(shape=(150, 150, 3)),
    layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D(pool_size=(2, 2)),

    # Second Convolutional Block
    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D(pool_size=(2, 2)),

    # Flatten and Fully Connected Layers
    layers.Flatten(),
    layers.Dense(1024, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.5),

    # Output Layer
    layers.Dense(7, activation='softmax')  # 7 classes for your teeth classification task
])

# Compile the model with gradient clipping
optimizer = Adam(learning_rate=0.001, clipvalue=1.0)  # Apply gradient clipping
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Model Summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 150, 150, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 75, 75, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 75, 75, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 37, 37, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 18, 18, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 41472)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │    42,468,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │         3,591 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 43,089,991 (164.38 MB)
#  Trainable params: 43,089,991 (164.38 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(train_generator, 
                    epochs=150,  # You can set the number of epochs as needed
                    validation_data=val_generator, 
                    callbacks=[reduce_lr, early_stopping],
                    batch_size=64)
# Out:
# Epoch 1/150
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 57s 551ms/step - accuracy: 0.1628 - loss: 2.1418 - val_accuracy: 0.2772 - val_loss: 1.8518 - learning_rate: 0.0010
# Epoch 2/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 342ms/step - accuracy: 0.2692 - loss: 1.8299 - val_accuracy: 0.2646 - val_loss: 1.7920 - learning_rate: 0.0010
# Epoch 3/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 345ms/step - accuracy: 0.2955 - loss: 1.7422 - val_accuracy: 0.3881 - val_loss: 1.5313 - learning_rate: 0.0010
# Epoch 4/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 347ms/step - accuracy: 0.3401 - loss: 1.6759 - val_accuracy: 0.3424 - val_loss: 1.6480 - learning_rate: 0.0010
# Epoch 5/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 346ms/step - accuracy: 0.3737 - loss: 1.6135 - val_accuracy: 0.4747 - val_loss: 1.4410 - learning_rate: 0.0010
# Epoch 6/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 347ms/step - accuracy: 0.4097 - loss: 1.5388 - val_accuracy: 0.4864 - val_loss: 1.3655 - learning_rate: 0.0010
# Epoch 7/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 348ms/step - accuracy: 0.4385 - loss: 1.5137 - val_accuracy: 0.5525 - val_loss: 1.2137 - learning_rate: 0.0010
# Epoch 8/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 35s 353ms/step - accuracy: 0.4701 - loss: 1.4042 - val_accuracy: 0.5302 - val_loss: 1.2823 - learning_rate: 0.0010
# Epoch 9/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 346ms/step - accuracy: 0.4834 - loss: 1.3914 - val_accuracy: 0.6158 - val_loss: 1.1245 - learning_rate: 0.0010
# Epoch 10/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 349ms/step - accuracy: 0.5035 - loss: 1.3139 - val_accuracy: 0.6226 - val_loss: 1.0690 - learning_rate: 0.0010
# Epoch 11/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 344ms/step - accuracy: 0.5282 - loss: 1.2813 - val_accuracy: 0.6255 - val_loss: 1.0193 - learning_rate: 0.0010
# Epoch 12/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 344ms/step - accuracy: 0.5326 - loss: 1.2328 - val_accuracy: 0.6712 - val_loss: 0.9565 - learning_rate: 0.0010
# Epoch 13/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.5672 - loss: 1.1565 - val_accuracy: 0.6284 - val_loss: 1.0413 - learning_rate: 0.0010
# Epoch 14/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 341ms/step - accuracy: 0.5668 - loss: 1.1829 - val_accuracy: 0.7062 - val_loss: 0.8819 - learning_rate: 0.0010
# Epoch 15/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.5965 - loss: 1.1168 - val_accuracy: 0.6897 - val_loss: 0.8882 - learning_rate: 0.0010
# Epoch 16/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 342ms/step - accuracy: 0.6085 - loss: 1.1210 - val_accuracy: 0.7422 - val_loss: 0.7736 - learning_rate: 0.0010
# Epoch 17/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 344ms/step - accuracy: 0.6458 - loss: 0.9858 - val_accuracy: 0.7004 - val_loss: 0.8278 - learning_rate: 0.0010
# Epoch 18/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.6358 - loss: 1.0266 - val_accuracy: 0.7539 - val_loss: 0.7053 - learning_rate: 0.0010
# Epoch 19/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.6508 - loss: 0.9352 - val_accuracy: 0.7685 - val_loss: 0.6611 - learning_rate: 0.0010
# Epoch 20/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.6680 - loss: 0.9427 - val_accuracy: 0.7811 - val_loss: 0.6522 - learning_rate: 0.0010
# Epoch 21/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 345ms/step - accuracy: 0.6746 - loss: 0.8750 - val_accuracy: 0.7879 - val_loss: 0.5979 - learning_rate: 0.0010
# Epoch 22/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.6919 - loss: 0.8999 - val_accuracy: 0.8298 - val_loss: 0.5728 - learning_rate: 0.0010
# Epoch 23/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 344ms/step - accuracy: 0.7060 - loss: 0.8215 - val_accuracy: 0.8230 - val_loss: 0.5062 - learning_rate: 0.0010
# Epoch 24/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 344ms/step - accuracy: 0.7207 - loss: 0.7679 - val_accuracy: 0.8337 - val_loss: 0.5073 - learning_rate: 0.0010
# Epoch 25/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 344ms/step - accuracy: 0.7390 - loss: 0.7262 - val_accuracy: 0.8375 - val_loss: 0.4756 - learning_rate: 0.0010
# Epoch 26/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 345ms/step - accuracy: 0.7578 - loss: 0.7190 - val_accuracy: 0.8551 - val_loss: 0.4342 - learning_rate: 0.0010
# Epoch 27/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.7233 - loss: 0.7640 - val_accuracy: 0.8502 - val_loss: 0.4873 - learning_rate: 0.0010
# Epoch 28/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 345ms/step - accuracy: 0.7423 - loss: 0.7247 - val_accuracy: 0.8142 - val_loss: 0.5165 - learning_rate: 0.0010
# Epoch 29/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 344ms/step - accuracy: 0.7375 - loss: 0.7444 - val_accuracy: 0.8911 - val_loss: 0.3529 - learning_rate: 0.0010
# Epoch 30/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 344ms/step - accuracy: 0.7698 - loss: 0.6435 - val_accuracy: 0.9008 - val_loss: 0.3212 - learning_rate: 0.0010
# Epoch 31/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 342ms/step - accuracy: 0.7556 - loss: 0.6967 - val_accuracy: 0.8959 - val_loss: 0.3531 - learning_rate: 0.0010
# Epoch 32/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 346ms/step - accuracy: 0.7928 - loss: 0.6168 - val_accuracy: 0.9027 - val_loss: 0.3132 - learning_rate: 0.0010
# Epoch 33/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.7945 - loss: 0.5943 - val_accuracy: 0.8881 - val_loss: 0.3281 - learning_rate: 0.0010
# Epoch 34/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 342ms/step - accuracy: 0.7524 - loss: 0.7019 - val_accuracy: 0.9173 - val_loss: 0.2983 - learning_rate: 0.0010
# Epoch 35/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 344ms/step - accuracy: 0.8019 - loss: 0.5739 - val_accuracy: 0.9212 - val_loss: 0.2705 - learning_rate: 0.0010
# Epoch 36/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 345ms/step - accuracy: 0.7925 - loss: 0.5607 - val_accuracy: 0.9222 - val_loss: 0.2565 - learning_rate: 0.0010
# Epoch 37/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 346ms/step - accuracy: 0.8071 - loss: 0.5530 - val_accuracy: 0.9232 - val_loss: 0.2524 - learning_rate: 0.0010
# Epoch 38/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 349ms/step - accuracy: 0.7859 - loss: 0.6063 - val_accuracy: 0.9339 - val_loss: 0.2295 - learning_rate: 0.0010
# Epoch 39/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 345ms/step - accuracy: 0.8109 - loss: 0.5423 - val_accuracy: 0.9348 - val_loss: 0.2315 - learning_rate: 0.0010
# Epoch 40/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 345ms/step - accuracy: 0.8066 - loss: 0.5475 - val_accuracy: 0.9261 - val_loss: 0.2236 - learning_rate: 0.0010
# Epoch 41/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 346ms/step - accuracy: 0.7978 - loss: 0.5809 - val_accuracy: 0.9348 - val_loss: 0.2183 - learning_rate: 0.0010
# Epoch 42/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.8449 - loss: 0.4385 - val_accuracy: 0.9222 - val_loss: 0.2565 - learning_rate: 0.0010
# Epoch 43/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.8150 - loss: 0.5574 - val_accuracy: 0.8998 - val_loss: 0.3061 - learning_rate: 0.0010
# Epoch 44/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.8362 - loss: 0.4754 - val_accuracy: 0.9494 - val_loss: 0.1747 - learning_rate: 0.0010
# Epoch 45/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.8422 - loss: 0.4533 - val_accuracy: 0.9251 - val_loss: 0.2364 - learning_rate: 0.0010
# Epoch 46/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 344ms/step - accuracy: 0.8445 - loss: 0.4361 - val_accuracy: 0.9436 - val_loss: 0.2002 - learning_rate: 0.0010
# Epoch 47/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.8445 - loss: 0.4501 - val_accuracy: 0.9543 - val_loss: 0.1671 - learning_rate: 0.0010
# Epoch 48/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 344ms/step - accuracy: 0.8319 - loss: 0.4631 - val_accuracy: 0.9358 - val_loss: 0.2082 - learning_rate: 0.0010
# Epoch 49/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 344ms/step - accuracy: 0.8546 - loss: 0.4347 - val_accuracy: 0.9591 - val_loss: 0.1706 - learning_rate: 0.0010
# Epoch 50/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.8560 - loss: 0.4278
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 345ms/step - accuracy: 0.8559 - loss: 0.4278 - val_accuracy: 0.9426 - val_loss: 0.2037 - learning_rate: 0.0010
# Epoch 51/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.8550 - loss: 0.4000 - val_accuracy: 0.9630 - val_loss: 0.1366 - learning_rate: 5.0000e-04
# Epoch 52/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 342ms/step - accuracy: 0.9056 - loss: 0.3008 - val_accuracy: 0.9630 - val_loss: 0.1237 - learning_rate: 5.0000e-04
# Epoch 53/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 344ms/step - accuracy: 0.8749 - loss: 0.3595 - val_accuracy: 0.9747 - val_loss: 0.1132 - learning_rate: 5.0000e-04
# Epoch 54/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 342ms/step - accuracy: 0.8921 - loss: 0.3193 - val_accuracy: 0.9796 - val_loss: 0.0974 - learning_rate: 5.0000e-04
# Epoch 55/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.9033 - loss: 0.2947 - val_accuracy: 0.9708 - val_loss: 0.0969 - learning_rate: 5.0000e-04
# Epoch 56/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.8880 - loss: 0.3182 - val_accuracy: 0.9737 - val_loss: 0.0911 - learning_rate: 5.0000e-04
# Epoch 57/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 345ms/step - accuracy: 0.9002 - loss: 0.3110 - val_accuracy: 0.9718 - val_loss: 0.0977 - learning_rate: 5.0000e-04
# Epoch 58/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.8966 - loss: 0.2978 - val_accuracy: 0.9718 - val_loss: 0.1207 - learning_rate: 5.0000e-04
# Epoch 59/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 342ms/step - accuracy: 0.8910 - loss: 0.3204 - val_accuracy: 0.9796 - val_loss: 0.0779 - learning_rate: 5.0000e-04
# Epoch 60/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 342ms/step - accuracy: 0.8952 - loss: 0.3053 - val_accuracy: 0.9747 - val_loss: 0.1036 - learning_rate: 5.0000e-04
# Epoch 61/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 346ms/step - accuracy: 0.9079 - loss: 0.2776 - val_accuracy: 0.9805 - val_loss: 0.0807 - learning_rate: 5.0000e-04
# Epoch 62/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9129 - loss: 0.2684
# Epoch 62: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 346ms/step - accuracy: 0.9128 - loss: 0.2686 - val_accuracy: 0.9825 - val_loss: 0.0911 - learning_rate: 5.0000e-04
# Epoch 63/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 345ms/step - accuracy: 0.9106 - loss: 0.2729 - val_accuracy: 0.9864 - val_loss: 0.0678 - learning_rate: 2.5000e-04
# Epoch 64/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 346ms/step - accuracy: 0.9270 - loss: 0.2151 - val_accuracy: 0.9883 - val_loss: 0.0640 - learning_rate: 2.5000e-04
# Epoch 65/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 344ms/step - accuracy: 0.9074 - loss: 0.2666 - val_accuracy: 0.9854 - val_loss: 0.0626 - learning_rate: 2.5000e-04
# Epoch 66/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.9206 - loss: 0.2307 - val_accuracy: 0.9864 - val_loss: 0.0577 - learning_rate: 2.5000e-04
# Epoch 67/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 347ms/step - accuracy: 0.9225 - loss: 0.2038 - val_accuracy: 0.9854 - val_loss: 0.0611 - learning_rate: 2.5000e-04
# Epoch 68/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 346ms/step - accuracy: 0.9281 - loss: 0.2295 - val_accuracy: 0.9864 - val_loss: 0.0632 - learning_rate: 2.5000e-04
# Epoch 69/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.9286 - loss: 0.2025
# Epoch 69: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 344ms/step - accuracy: 0.9285 - loss: 0.2025 - val_accuracy: 0.9844 - val_loss: 0.0681 - learning_rate: 2.5000e-04
# Epoch 70/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 346ms/step - accuracy: 0.9181 - loss: 0.2259 - val_accuracy: 0.9883 - val_loss: 0.0536 - learning_rate: 1.2500e-04
# Epoch 71/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.9223 - loss: 0.2160 - val_accuracy: 0.9874 - val_loss: 0.0539 - learning_rate: 1.2500e-04
# Epoch 72/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 35s 350ms/step - accuracy: 0.9386 - loss: 0.1889 - val_accuracy: 0.9883 - val_loss: 0.0516 - learning_rate: 1.2500e-04
# Epoch 73/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.9371 - loss: 0.1905 - val_accuracy: 0.9883 - val_loss: 0.0542 - learning_rate: 1.2500e-04
# Epoch 74/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.9216 - loss: 0.1980 - val_accuracy: 0.9893 - val_loss: 0.0497 - learning_rate: 1.2500e-04
# Epoch 75/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.9304 - loss: 0.2026 - val_accuracy: 0.9844 - val_loss: 0.0576 - learning_rate: 1.2500e-04
# Epoch 76/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 344ms/step - accuracy: 0.9246 - loss: 0.2187 - val_accuracy: 0.9874 - val_loss: 0.0540 - learning_rate: 1.2500e-04
# Epoch 77/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.9355 - loss: 0.1927
# Epoch 77: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.9355 - loss: 0.1926 - val_accuracy: 0.9864 - val_loss: 0.0524 - learning_rate: 1.2500e-04
# Epoch 78/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 346ms/step - accuracy: 0.9456 - loss: 0.1664 - val_accuracy: 0.9893 - val_loss: 0.0476 - learning_rate: 6.2500e-05
# Epoch 79/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 342ms/step - accuracy: 0.9332 - loss: 0.1869 - val_accuracy: 0.9874 - val_loss: 0.0497 - learning_rate: 6.2500e-05
# Epoch 80/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.9459 - loss: 0.1801 - val_accuracy: 0.9874 - val_loss: 0.0489 - learning_rate: 6.2500e-05
# Epoch 81/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.9310 - loss: 0.1873 - val_accuracy: 0.9893 - val_loss: 0.0458 - learning_rate: 6.2500e-05
# Epoch 82/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 341ms/step - accuracy: 0.9340 - loss: 0.1818 - val_accuracy: 0.9883 - val_loss: 0.0488 - learning_rate: 6.2500e-05
# Epoch 83/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 342ms/step - accuracy: 0.9383 - loss: 0.1887 - val_accuracy: 0.9893 - val_loss: 0.0465 - learning_rate: 6.2500e-05
# Epoch 84/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.9357 - loss: 0.1972
# Epoch 84: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.9357 - loss: 0.1971 - val_accuracy: 0.9883 - val_loss: 0.0478 - learning_rate: 6.2500e-05
# Epoch 85/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 342ms/step - accuracy: 0.9442 - loss: 0.1778 - val_accuracy: 0.9893 - val_loss: 0.0445 - learning_rate: 3.1250e-05
# Epoch 86/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 341ms/step - accuracy: 0.9401 - loss: 0.1775 - val_accuracy: 0.9893 - val_loss: 0.0436 - learning_rate: 3.1250e-05
# Epoch 87/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.9416 - loss: 0.1650 - val_accuracy: 0.9903 - val_loss: 0.0429 - learning_rate: 3.1250e-05
# Epoch 88/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 341ms/step - accuracy: 0.9433 - loss: 0.1818 - val_accuracy: 0.9893 - val_loss: 0.0446 - learning_rate: 3.1250e-05
# Epoch 89/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 35s 353ms/step - accuracy: 0.9371 - loss: 0.1813 - val_accuracy: 0.9893 - val_loss: 0.0448 - learning_rate: 3.1250e-05
# Epoch 90/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.9511 - loss: 0.1668
# Epoch 90: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 345ms/step - accuracy: 0.9511 - loss: 0.1668 - val_accuracy: 0.9893 - val_loss: 0.0434 - learning_rate: 3.1250e-05
# Epoch 91/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 346ms/step - accuracy: 0.9382 - loss: 0.1919 - val_accuracy: 0.9903 - val_loss: 0.0443 - learning_rate: 1.5625e-05
# Epoch 92/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 344ms/step - accuracy: 0.9430 - loss: 0.1630 - val_accuracy: 0.9893 - val_loss: 0.0427 - learning_rate: 1.5625e-05
# Epoch 93/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 342ms/step - accuracy: 0.9425 - loss: 0.1662 - val_accuracy: 0.9903 - val_loss: 0.0423 - learning_rate: 1.5625e-05
# Epoch 94/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 342ms/step - accuracy: 0.9300 - loss: 0.1920 - val_accuracy: 0.9912 - val_loss: 0.0423 - learning_rate: 1.5625e-05
# Epoch 95/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.9368 - loss: 0.1758 - val_accuracy: 0.9922 - val_loss: 0.0415 - learning_rate: 1.5625e-05
# Epoch 96/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 342ms/step - accuracy: 0.9430 - loss: 0.1812 - val_accuracy: 0.9912 - val_loss: 0.0423 - learning_rate: 1.5625e-05
# Epoch 97/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 340ms/step - accuracy: 0.9440 - loss: 0.1751 - val_accuracy: 0.9893 - val_loss: 0.0425 - learning_rate: 1.5625e-05
# Epoch 98/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9445 - loss: 0.1698
# Epoch 98: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 340ms/step - accuracy: 0.9445 - loss: 0.1699 - val_accuracy: 0.9903 - val_loss: 0.0427 - learning_rate: 1.5625e-05
# Epoch 99/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 342ms/step - accuracy: 0.9439 - loss: 0.1795 - val_accuracy: 0.9903 - val_loss: 0.0429 - learning_rate: 7.8125e-06
# Epoch 100/150
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 34s 341ms/step - accuracy: 0.9445 - loss: 0.1737 - val_accuracy: 0.9903 - val_loss: 0.0426 - learning_rate: 7.8125e-06

# %%
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9965 - loss: 0.0342
# Test Accuracy: 0.9912451505661011

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    """
    Plots training and validation accuracy and loss separately.

    Parameters:
    history: History object returned by model.fit()
    """
    # Extract accuracy and loss data from the history object
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    # Plot training and validation accuracy
    plt.figure(figsize=(12, 5))

    # Accuracy plot
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'b', label='Training Accuracy')
    plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Loss plot
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'b', label='Training Loss')
    plt.plot(epochs, val_loss, 'r', label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Show the plots
    plt.tight_layout()
    plt.show()
# Plot the training history
plot_training_history(history)

# %%
model.save('teeth_classification_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
